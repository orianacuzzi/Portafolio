# %% [markdown]
# <a href="https://colab.research.google.com/github/orianacuzzi/Portafolio/blob/main/EstrategiaComercial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hola! 😀
#
# Soy **Jaime Paz** y mis amigos me suelen llamar James! - *"Tranquilo, no juego en el Real Madrid"* ⚽😅. Sí, como el futbolista James Rodríguez, pero en versión científico de datos… y mejor no me digas como a él. 😉
#
# Como tu revisor en TripleTen, estoy aquí para ayudarte a pulir tu código y tu forma de trabajar con datos. Si algo necesita un ajuste, no te preocupes: la idea es que cada comentario te acerque más a cómo se trabaja en un entorno profesional y que tu proyecto brille con todo su potencial.
#
# Cada vez que encuentre un detalle importante en tu proyecto, te lo señalaré para que puedas corregirlo y seguir creciendo. Si en algún punto no logras resolver algo, también estoy para guiarte en próximos intentos de revisión. 🔁
#
# Es muy importante que, cuando veas mis comentarios, **no los muevas, no los modifiques y no los borres**. Así mantenemos un historial claro de lo que ya revisamos y de tus avances. ✅
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente tu proyecto para asegurar que cumpla con los requisitos y te daré comentarios usando el siguiente formato:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Esta parte está bien implementada y contribuye de forma positiva al análisis o al proyecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Esta parte funciona, pero todavía se puede reforzar para que quede más clara, más completa o más sólida.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - Aquí hay un punto importante por corregir porque afecta la validez del análisis, la implementación o la entrega.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
#
#
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Tu proyecto es excepcional y has logrado cubrir los objetivos del mismo. Abajo he dejado mis comentarios y unas pequeñas recomendaciones para que tomes en cuenta en un futuro y te hagan ¡un máster en Data!
#
# ¡Felicidades!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - Hola Oriana. Te comento, que seguimos teniendo el mismo problema para abrir el archivo. Te recomiendo que para tu siguiente entrega, te asegures que el archivo adjunto sea un archivo tipo ".pbix" exclusivamente. Otra cosa, es asegurarte que abra no solo un en tu PC, para garantizar la entrega (si es posible), conviene intentes abrir el mismo archivo desde otro pc disponible.
#
# Y no olvides, descargar y actualizar a la ultima ver. de **Power BI.** Esto no va a alterar en absoluto tu entrega, solo va a alinearnos y poder proceder a iniciar a revisar tu proyecto, ya que ha pasado por 2 iteraciones actualmente. Evitemos una tercera al mayor coste 💪.
#
# **https://www.microsoft.com/en-us/download/details.aspx?id=58494**
#
# </div>

# %% [markdown]
# Como lo has presentado en tu segunda entrega:

# %% [markdown]
# ![image.png](attachment:afb2fdac-663f-45c7-8431-579d62b35622.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - Hola Oriana! Te comento que tengo problemas al abrir el archivo PBIX que has subido a la plataforma (en la siguiente celda puedes encontrar el error). Para tu siguiente entrega, conviene asegurarte (por experiencias pasadas en Power BI) que tu archivo PBIX no contenga enlaces privados y sobre todo, que tengas la version mas actualizada instalada en tu computadora.
#
# **Espero tu siguiente entrega pueda ser correcta, de lo contrario voy a estar solicitando apoyo externo para facilitar y agilizar tu entrega**
# </div>

# %% [markdown]
# ![image.png](attachment:a206ff92-6963-42e0-8e70-2f042819a728.png)

# %% [markdown]
# # 📊 Proyecto: Análisis Comercial Inmobiliario
#
# El sector inmobiliario necesita evaluar su **desempeño comercial** para comprender su crecimiento, rentabilidad y comportamiento de clientes.
#
# Se solicita construir un **dashboard ejecutivo** que permita analizar ventas, clientes y propiedades para apoyar decisiones estratégicas basadas en datos.

# %% [markdown]
# # 📂 Descripción de los Datasets
#
# 🔹 **hecho_ventas_propiedades**
# Tabla de hechos con las transacciones de venta (precio, cliente, propiedad, canal, fecha).
#
# 🔹 **dim_clientes**
# Información y segmentación de clientes.
#
# 🔹 **dim_propiedades**
# Características de las propiedades (tipo, tamaño, ubicación, etc).
#
# 🔹 **dim_fecha**
# Tabla calendario que deberá ser creada como parte del modelado.

# %% [markdown]
# # 🎯 Preguntas que el dashboard debe responder
#
# **Desempeño general**
#
# - ¿Cuál es el **ingreso total** generado por la empresa?
# - ¿Cuántas **propiedades se han vendido**?
# - ¿Cuál es el **precio promedio de venta**?
# - ¿Cuál es la **comisión total** generada por la empresa?
#
# **Análisis comercial**
#
# - ¿Qué **tipo de propiedad genera más ingresos**?
# - ¿Qué **segmento de clientes compra más propiedades**?
# - ¿Qué canal de venta **genera mayor ingresos**?
#
#
# **Análisis temporal**
#
# - ¿Cómo evolucionan las **ventas en el tiempo**?
# - ¿El negocio está **creciendo año contra año**?
# - ¿Cómo va el desempeño **acumulado del año actual (YTD)**?
#
# **Cohortes de clientes**
#
# - ¿Los clientes **vuelven a comprar** después de su primera compra?
# - ¿Qué **cohortes de clientes generan más compras/ingresos con el tiempo**?

# %% [markdown]
# ## 🧹 Paso 1: Limpieza de datos
#
# Antes del modelado, debes validar y depurar la información.
#
# ### Tipos de datos
#
# - `fecha_venta` debe estar en formato **Date**.
# - Los campos numéricos deben estar correctamente formateados.
# - `porcentaje_comision` debe estar en formato **porcentaje**.
#
# ### Valores nulos
#
# - Revisar valores **nulos** en las tablas.
# - Justificar si deben eliminarse o mantenerse.
#
# ### Duplicados
#
# - Validar que no existan duplicados en las claves primarias de:
#   - `dim_clientes`
#   - `dim_propiedades`

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📅 Paso 2: Creación de tabla calendario
#
# Si vas a realizar el dashboard en **Power BI**, deberás crear una tabla calendario llamada **dim_fecha**.
#
# **Requisitos (solo para Power BI):**
#
# - Utilizar las funciones `CALENDAR` y `ADDCOLUMNS`.
# - El rango de fechas debe construirse dinámicamente desde la **fecha mínima** hasta la **fecha máxima** de ventas en `hecho_ventas_propiedades`.
# - Incluir como mínimo las siguientes columnas:
#   - Año
#   - Mes (nombre)
#   - Número de mes
#   - Año-Mes (formato `YYYY-MM`)
#
# > ⚠️ **Nota:**
# > Si utilizas **Tableau**, no necesitas crear esta tabla. Puedes usar directamente el campo `fecha_venta` de la tabla `hecho_ventas_propiedades`, ya que Tableau genera automáticamente las jerarquías de fecha.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🧩 Paso 3: Modelado de datos
#
# ### Modelo requerido: Esquema estrella
#
# El modelo debe estructurarse en formato estrella:
#
# - `hecho_ventas_propiedades` como tabla central.
# - Tablas dimensionales conectadas:
#   - `dim_clientes`
#   - `dim_propiedades`
#   - `dim_fecha` (creada por ti, en caso de que aplique)
#
# Requisitos de las relaciones:
#
# - Cardinalidad **uno a muchos (1:*)**
# - Dirección de filtro **simple (single)**
# - Relaciones basadas en las claves correctas
# - Todas las relaciones deben estar **activas**

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📊 Paso 4: Creación de medidas
#
# En este paso deberás crear las **medidas necesarias para responder las preguntas de negocio del dashboard**.
#
# Las medidas pueden implementarse en **Power BI (DAX)** o como **Calculated Fields en Tableau**.
#
# ---
#
# ### 4.1 🔹 Medidas base
#
# Crear como mínimo las siguientes medidas:
#
# - **Ingreso Total** (suma del `precio_venta`)
# - **Cantidad de Ventas**
# - **Ticket Promedio**
# - **Comisión Total**
#
# Estas métricas permitirán analizar el desempeño general del negocio.
#
# ---
#
# ### 4.2 🔹 Medidas con contexto de filtro
#
# Debes crear **al menos 2 medidas** que modifiquen el contexto de filtro.
#
# En este caso se utilizarán **medidas de participación (%)**, que permiten entender **qué proporción del ingreso total aporta cada categoría**.
#
# Las medidas que deben construirse son:
#
# - **Participación de ingresos por tipo de propiedad**
# - **Participación de ingresos por canal de venta**
# - **Participación de ingresos por segmento de cliente**
#
# Para ello:
# - Modifica el contexto de filtro con las funciones propias de cada herramienta
#   - En Power BI, usa `CALCULATE`
#   - En Tableau, usa expresiones como `FIXED` (LOD)
#
# Elimina el filtro de la dimensión correspondiente para obtener el total
#
# Asegúrate de que el denominador represente el total sin el filtro de la categoría, mientras que el numerador sí lo conserva.
#
# Estas medidas se utilizarán principalmente como **tooltip o etiqueta adicional en los gráficos** del dashboard para complementar el análisis.
#
# ---
#
# ### 4.3 🔹 Inteligencia de tiempo
#
# Utilizando la tabla **`dim_fecha`** (Power BI) o las funciones de fecha en Tableau, debes crear al menos 2 de las siguientes medidas:
#
# - **Ventas Year to Date (YTD)**
# - **Ventas Month to Date (MTD)**
# - **Ventas del año anterior**
# - **Crecimiento Year over Year (YoY)**
#
# Estas métricas permitirán analizar la evolución del negocio en el tiempo.
#
# ---
#
# ### 4.4 🔹 Medidas para análisis de cohortes
#
# Debes crear cálculos que permitan analizar **si los clientes vuelven a comprar después de su primera compra**.
#
# ⚠️ Estos cálculos deben crearse como **columnas calculadas**, no como medidas.
# Todas deben crearse en la tabla **`hecho_ventas_propiedades`**.
#
# Debes crear como mínimo:
#
# - **Primera compra por cliente** → fecha mínima de compra de cada cliente.
# - **Mes Cohorte** → mes en que el cliente realizó su **primera compra** (mes de adquisición).
# - **Mes Venta** → mes en que ocurre cada transacción. Este campo permite identificar **cuándo el cliente vuelve a comprar** después de su primera compra.
#
# Estos cálculos permitirán construir una **matriz de cohortes** donde:
#
# - **Filas** representen el **mes de cohorte**
# - **Columnas** representen el **mes de venta**
# - **Valores** muestren **cantidad de ventas o ingresos**
#
# ---

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📊 Paso 5: Estructura del reporte
#
# El dashboard debe contener **mínimo tres páginas**.
#
# ---
#
# ### 5.1 1️⃣ Overview Ejecutivo
#
# Debe mostrar **el desempeño general del negocio**.
#
# Incluir minimo 4 KPIs:
#
# - **KPIs principales**
#   - Ingreso Total
#   - Cantidad de Ventas
#   - Ticket Promedio
#   - Comisión Total
#
# - **Tendencia de ventas en el tiempo**
#
# - **Ingresos o ventas por ciudad**
#
# - **Crecimiento Year over Year (YoY)**
#
# ---
#
# ### 5.2 2️⃣ Análisis Comercial
#
# Debe analizar **qué productos, canales y clientes generan más ingresos**.
#
# Incluir:
#
# - **Ingreso por tipo de propiedad**
# - **Ventas o ingresos por canal de venta**
# - **Ventas o ingresos por segmento de cliente**
# - **Tabla con formato condicional (colores semáforo)**
#   Sugerencia de campos:
#   - tipo_propiedad
#   - Ingreso Total
#   - Cantidad Ventas
#   - Ticket Promedio
#   Aplicar **formato condicional** para resaltar las categorías con mayor desempeño.
#
# Se recomienda usar **tooltips con medidas de participación (%)**.
#
# ---
#
# ### 5.3 3️⃣ Análisis de Cohortes
#
# Debe analizar **recurrencia de clientes**.
#
# Incluir:
#
# - **Matriz de cohortes**
#   - Filas → Mes Cohorte
#   - Columnas → Mes Venta
#   - Valores → Cantidad Ventas o Ingreso Total
#
# Esto permitirá observar **si los clientes vuelven a comprar y comparar cohortes en el tiempo**.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 📝Paso 6:  Resumen Ejecutivo
#
# Escribe aquí un resumen con:
#
# - hallazgos clave
# - El ingreso total del periodo fue de 6,01 millones generado por aproximadamente 8,5 mil – 9 mil ventas.
# El tipo de propiedad que genera mayor revenue es Casa, con alrededor de $2,24 mil millones en ingresos.
# La ciudad con mayor volumen de ventas e ingresos es Ciudad de México.
# El canal de venta más eficiente en términos de ingresos es Corredor, concentrando aproximadamente el 72,85% de la participación.
# El segmento de compradores “Primera vez” representa la mayor proporción del ingreso total.
# El negocio presenta un crecimiento positivo con un 111,14% YoY, aunque se observa desaceleración en los meses más recientes
#
# - métricas principales
# - Ingreso Total: 6,01 millones
# - Cantidad de Ventas: 8.500 – 9.000 ventas
# - Ticket Promedio: 707,35 mil
# - Comisión Total: 201 millones
# - Crecimiento YoY: 111,14%
# - Clientes Recurrentes: 3 mil
# - Clientes que recompraron: 2 mil
#
# - insights accionables
# - El segmento Primera vez concentra la mayor parte de los ingresos, indicando una fuerte dependencia de nuevos compradores.
# Las cohortes iniciales de 2023 muestran mayores niveles de recompra y recurrencia frente a las cohortes recientes.
# Existe una disminución progresiva en clientes recurrentes a lo largo del tiempo, lo que puede indicar desgaste en retención.
# El canal Corredor domina claramente la generación de ingresos, mientras que el canal Directo mantiene menor participación.
# Las propiedades tipo Casa presentan el mejor desempeño tanto en ingresos como en volumen de ventas.
# Aunque el crecimiento anual es positivo, la tendencia mensual del ingreso muestra una ligera desaceleración reciente.
#
# - recomendaciones estratégicas
# - Priorizar la comercialización de propiedades tipo Casa, ya que lideran el revenue total.
# - Fortalecer el canal de ventas Corredor, optimizando alianzas y comisiones para mantener su desempeño.
# - Diseñar campañas de fidelización y retención para aumentar la recompra en cohortes recientes.
# - Implementar estrategias de seguimiento postventa para incrementar la recurrencia de clientes.
# - Diversificar la captación hacia segmentos de mayor valor como Inversionistas y Alto patrimonio.
# - Monitorear la caída progresiva en recurrencia para prevenir desaceleraciones futuras en ingresos.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Puedes entregar el proyecto utilizando **Power BI o Tableau**.
#
# Incluye **uno de los siguientes**:
#
# - 🔗 Link público del dashboard publicado en **Power BI Service o Tableau Public / Tableau Cloud**
# - 🔗 Link de **Google Drive o OneDrive** con el archivo `.pbix` del proyecto
# - ✅ Confirmación de que el archivo `.pbix` fue subido según las instrucciones del curso
#
# ### 📎 Enlace del proyecto
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
subi mi proyecto a la plataforma corregido
# Out:
#   Cell In[1], line 1
#     subi mi proyecto a la plataforma corregido
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Tabla completa de evaluación
#
# | Paso | Criterio | Estado | Puntaje obtenido | Puntaje máximo | Comentario breve |
# |---|---|---|---:|---:|---|
# | 1 | Tipos de datos | ✅ Logrado | 4 | 4 | Configuraste correctamente `fecha_venta`, los campos numéricos y `porcentaje_comision`. |
# | 1 | Valores nulos | ❌ No logrado | 0 | 3 | No dejaste una validación clara ni el criterio de tratamiento para los nulos. |
# | 1 | Duplicados | ❌ No logrado | 0 | 3 | No pude validar una revisión explícita de unicidad en clientes y propiedades. |
# | 2 | Tabla `dim_fecha` | ✅ Logrado | 5 | 5 | Creaste una tabla calendario dinámica con `CALENDAR` y `ADDCOLUMNS`. |
# | 2 | Columnas obligatorias | ✅ Logrado | 5 | 5 | Incluiste Año, Mes, Número de mes y Año-Mes. |
# | 3 | Definición de vistas | ✅ Logrado | 4 | 4 | Organizaste el dashboard en vistas alineadas al objetivo comercial. |
# | 3 | Selección de KPIs | ✅ Logrado | 4 | 4 | Elegiste KPIs centrales para ingresos, volumen, ticket y comisión. |
# | 3 | Elección de gráficos | 🟡 Recomendación | 3 | 4 | Los visuales son adecuados, pero los gráficos temporales quedaron ordenados por valor y no por fecha. |
# | 3 | Jerarquía visual | ✅ Logrado | 3 | 3 | La lectura general por página es clara y prioriza bien los indicadores clave. |
# | 4 | Medidas base | ✅ Logrado | 5 | 5 | Construiste correctamente ingreso total, cantidad de ventas, ticket promedio y comisión total. |
# | 4 | Medidas con contexto | ✅ Logrado | 5 | 5 | Creaste participaciones por tipo de propiedad, canal y segmento con contexto de filtro correcto. |
# | 4 | Inteligencia de tiempo | ✅ Logrado | 5 | 5 | Incluiste YTD, MTD, año anterior y YoY. |
# | 4 | Cohortes | ✅ Logrado | 5 | 5 | Definiste Primera Compra, Mes Cohorte y Mes Venta de forma funcional para la matriz. |
# | 5 | Vista 1 — Overview Ejecutivo | 🟡 Recomendación | 6 | 8 | La vista incluye KPIs, ciudad y YoY, pero la tendencia temporal no está en orden cronológico. |
# | 5 | Vista 2 — Análisis Comercial | ✅ Logrado | 7 | 7 | Cubriste tipo de propiedad, canal, segmento y tabla con formato condicional. |
# | 5 | Vista 3 — Cohortes | ✅ Logrado | 5 | 5 | La matriz de cohortes está bien estructurada y responde al análisis de recurrencia. |
# | 6 | Hallazgos clave | 🟡 Recomendación | 4 | 5 | Identificaste bien los líderes del negocio, aunque el ingreso total quedó descrito con una unidad inconsistente. |
# | 6 | Insights accionables | ✅ Logrado | 5 | 5 | Tus insights conectan segmentos, recurrencia, canales y evolución del negocio. |
# | 6 | Recomendaciones estratégicas | ✅ Logrado | 5 | 5 | Propusiste acciones concretas de priorización, retención y crecimiento. |
# | 7 | Link del proyecto | ✅ Logrado | 5 | 5 | La entrega quedó accesible para revisión. |
# | 7 | Entrega completa y verificable | ✅ Logrado | 5 | 5 | La entrega permite revisar el trabajo de punta a punta. |
#
# ## Subtotal Paso 1
#
# **4/10**
#
# ## Comentario Paso 1
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Configuraste bien los tipos de datos, pero todavía te falta dejar trazable la revisión de nulos y duplicados. Te recomiendo documentar ese control de calidad para que tus conclusiones partan de una base totalmente confiable.
# </div>
#
# ## Subtotal Paso 2
#
# **10/10**
#
# ## Comentario Paso 2
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Construiste correctamente tu tabla calendario y agregaste todas las columnas solicitadas. Esta parte quedó bien resuelta y te da una base sólida para el análisis temporal.
# </div>
#
# ## Subtotal Paso 3
#
# **14/15**
#
# ## Comentario Paso 3
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Definiste bien las vistas, los KPIs y la estructura general del dashboard. Como mejora prioritaria, ordena los gráficos temporales por fecha para que la lectura del crecimiento y la recurrencia sea coherente con el comportamiento real del negocio.
# </div>
#
# ## Subtotal Paso 4
#
# **20/20**
#
# ## Comentario Paso 4
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Tu trabajo con medidas está muy completo. Cubriste métricas base, contexto de filtro, inteligencia de tiempo y cohortes, y eso hace que el dashboard responda bien a las preguntas de negocio.
# </div>
#
# ## Subtotal Paso 5
#
# **18/20**
#
# ## Comentario Paso 5
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - La estructura por páginas está bien planteada y la vista comercial destaca especialmente por su claridad. El ajuste pendiente está en los gráficos de tendencia, porque al estar ordenados por valor en vez de fecha pueden llevar a interpretaciones temporales incorrectas.
# </div>
#
# ## Subtotal Paso 6
#
# **14/15**
#
# ## Comentario Paso 6
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - Tu resumen ejecutivo está bien orientado y propone acciones útiles para el negocio. Solo te recomiendo cuidar la unidad con la que expresas el ingreso total para que el mensaje quede completamente preciso y consistente con los valores del dashboard.
# </div>
#
# ## Subtotal Paso 7
#
# **10/10**
#
# ## Comentario Paso 7
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - La entrega quedó completa y revisable. Esto facilita validar tanto la parte técnica como la parte analítica de tu proyecto.
# </div>
#
# ## Total final
#
# **90/100** **EXCELENTE 🏅🏅🏅**
#
# ## Conclusión final
#
# ### Conclusión general
#
# **Buen trabajo Oriana!** Tu proyecto muestra un muy buen dominio del flujo completo de construcción de un dashboard analítico. Resolviste con solidez la parte de modelado analítico, medidas DAX, estructura de páginas y lectura de negocio, y eso se refleja en un resultado funcional y bien orientado a la toma de decisiones.
#
# ### Puntos fuertes
# - Construiste correctamente las medidas clave del negocio y las métricas de inteligencia de tiempo.
# - Diseñaste tres vistas útiles y bien diferenciadas para overview, análisis comercial y cohortes.
# - Desarrollaste un resumen ejecutivo con hallazgos, insights y recomendaciones accionables.
# - La vista comercial y la matriz de cohortes quedaron especialmente bien logradas.
#
# ### Sugerencias de mejora
# - Documenta siempre la validación de nulos y duplicados para fortalecer la confiabilidad del análisis.
# - Corrige el orden de los gráficos temporales para que usen una secuencia cronológica real.
# - Revisa la redacción de unidades en las métricas ejecutivas para evitar inconsistencias entre valor y descripción.
#
#
# **Vas por muy buen camino...**  Ya tienes una base técnica sólida y una lectura de negocio clara; si refuerzas el control de calidad de datos y ajustas la configuración de las series temporales, tu dashboard va a ganar todavía más precisión y nivel profesional.
